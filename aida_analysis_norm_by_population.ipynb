# %% [markdown]
# # Let's try analyzeing ATECO in the region

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import calendar
import folium
import geopandas as gpd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import math
import folium
import datetime
from os import listdir
from os.path import isfile, join

from matplotlib import gridspec
from matplotlib.backends.backend_pdf import PdfPages

import statsmodels.api as sm
from stargazer.stargazer import Stargazer

# %%
ateco2007 = pd.read_csv('quake_data/Ateco2007.csv', sep=';')
ateco1 = ateco2007[ateco2007['Codice Ateco 2007'].str.len()==1].reset_index().drop(['index','Codice Ateco 2007'],axis=1)
ateco1.columns = ['ateco1','desc1']
ateco2 = ateco2007[ateco2007['Codice Ateco 2007'].str.len()==2].reset_index().drop('index',axis=1)
ateco2.columns = ['ateco1','ateco2','desc2']
ateco = pd.merge(ateco1,ateco2)
ateco
# Out:
#    ateco1                                              desc1 ateco2  \
# 0       A                  AGRICOLTURA, SILVICOLTURA E PESCA     01
# 1       A                  AGRICOLTURA, SILVICOLTURA E PESCA     02
# 2       A                  AGRICOLTURA, SILVICOLTURA E PESCA     03
# 3       B           ESTRAZIONE DI MINERALI DA CAVE E MINIERE     05
# 4       B           ESTRAZIONE DI MINERALI DA CAVE E MINIERE     06
# ..    ...                                                ...    ...
# 83      S                          ALTRE ATTIVITÀ DI SERVIZI     95
# 84      S                          ALTRE ATTIVITÀ DI SERVIZI     96
# 85      T  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...     97
# 86      T  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...     98
# 87      U      ORGANIZZAZIONI ED ORGANISMI EXTRATERRITORIALI     99
#
#                                                 desc2
# 0   COLTIVAZIONI AGRICOLE E PRODUZIONE DI PRODOTTI...
# 1          SILVICOLTURA ED UTILIZZO DI AREE FORESTALI
# 2                                PESCA E ACQUACOLTURA
# 3               ESTRAZIONE DI CARBONE (ESCLUSA TORBA)
# 4    ESTRAZIONE DI PETROLIO GREGGIO E DI GAS NATURALE
# ..                                                ...
# 83  RIPARAZIONE DI COMPUTER E DI BENI PER USO PERS...
# 84           ALTRE ATTIVITÀ DI SERVIZI PER LA PERSONA
# 85  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 86  PRODUZIONE DI BENI E SERVIZI INDIFFERENZIATI P...
# 87      ORGANIZZAZIONI ED ORGANISMI EXTRATERRITORIALI
#
# [88 rows x 4 columns]

# %%
# aida_crateri3.csv contiene proprio le aziende create prima del terremoto e che erano attive al momento del terremoto

aida = pd.read_csv('quake_data/aida_crateri3.csv')
aida = aida[['Comune','Ricavi delle vendite migl EUR Ultimo anno disp.','Dipendenti Ultimo anno disp.','Stato giuridico','ateco2']]
aida.columns = ['Comune','ricavi','dipendenti','stato','ateco2']

aida['ateco2'] = aida['ateco2'].astype('string')
m = aida['ateco2'].str.len().max()
aida['ateco2'] = aida['ateco2'].str.rjust(m, '0').astype('str').str[0:2]

aida[aida['ateco2']=='02']
# Out:
#                    Comune  ricavi  dipendenti                      stato  \
# 115              Fabriano  2010.0           3                     Attiva
# 183              Fabriano   601.0           0                     Attiva
# 190              Fabriano   537.0          42                    Fallita
# 249              Fabriano   250.0          30          Cessata (Fusione)
# 434              Fabriano     1.0           2                     Attiva
# ...                   ...     ...         ...                        ...
# 52484      Fara in Sabina   160.0           3                     Attiva
# 52750    Caramanico Terme   136.0           1                     Attiva
# 52911  Magliano de' Marsi   132.0           5                     Attiva
# 53167        Massa d'Albe     0.0           0                     Attiva
# 53181         Sante Marie    14.0           1  Cessata (In liquidazione)
#
#       ateco2
# 115       02
# 183       02
# 190       02
# 249       02
# 434       02
# ...      ...
# 52484     02
# 52750     02
# 52911     02
# 53167     02
# 53181     02
#
# [143 rows x 5 columns]

# %%
aida_ateco = pd.merge(aida.astype('str') , ateco.astype('str') , how='left', on='ateco2')
aida_ateco.loc[aida_ateco['ricavi'] == 'n.d.','ricavi'] = np.nan
aida_ateco.loc[aida_ateco['dipendenti'] == 'n.d.','dipendenti'] = np.nan
aida_ateco['ricavi'] = aida_ateco['ricavi'].astype('float')
aida_ateco['dipendenti'] = aida_ateco['dipendenti'].astype('float')
aida_ateco[aida_ateco['ateco1']=='A']
aida_ateco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53289 entries, 0 to 53288
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Comune      53289 non-null  object
#  1   ricavi      53289 non-null  float64
#  2   dipendenti  53289 non-null  float64
#  3   stato       53289 non-null  object
#  4   ateco2      53289 non-null  object
#  5   ateco1      53289 non-null  object
#  6   desc1       53289 non-null  object
#  7   desc2       53289 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 3.7+ MB

# %%
aida_ateco.loc[aida_ateco['Comune']=='Acciano',:]
# Out:
#         Comune  ricavi  dipendenti   stato ateco2 ateco1  \
# 52738  Acciano   120.0         2.0  Attiva     46      G
# 52739  Acciano    38.0         1.0  Attiva     81      N
# 52740  Acciano     8.0         0.0  Attiva     46      G
#
#                                                    desc1  \
# 52738  COMMERCIO ALL'INGROSSO E AL DETTAGLIO; RIPARAZ...
# 52739  NOLEGGIO, AGENZIE DI VIAGGIO, SERVIZI DI SUPPO...
# 52740  COMMERCIO ALL'INGROSSO E AL DETTAGLIO; RIPARAZ...
#
#                                                    desc2
# 52738  COMMERCIO ALL'INGROSSO (ESCLUSO QUELLO DI AUTO...
# 52739        ATTIVITÀ DI SERVIZI PER EDIFICI E PAESAGGIO
# 52740  COMMERCIO ALL'INGROSSO (ESCLUSO QUELLO DI AUTO...

# %%
vc = aida_ateco['desc1'].value_counts().to_frame()
vc['p'] = vc['desc1']/vc['desc1'].sum()*100
vc
# Out:
#                                                     desc1          p
# COMMERCIO ALL'INGROSSO E AL DETTAGLIO; RIPARAZI...   9852  18.487868
# ATTIVITÀ MANIFATTURIERE                              9660  18.127569
# COSTRUZIONI                                          9443  17.720355
# ATTIVITA' IMMOBILIARI                                6251  11.730376
# ATTIVITÀ PROFESSIONALI, SCIENTIFICHE E TECNICHE      3505   6.577342
# ATTIVITÀ DEI SERVIZI DI ALLOGGIO E DI RISTORAZIONE   3074   5.768545
# NOLEGGIO, AGENZIE DI VIAGGIO, SERVIZI DI SUPPOR...   2197   4.122802
# SERVIZI DI INFORMAZIONE E COMUNICAZIONE              2085   3.912627
# TRASPORTO E MAGAZZINAGGIO                            1594   2.991236
# AGRICOLTURA, SILVICOLTURA E PESCA                    1403   2.632814
# SANITA' E ASSISTENZA SOCIALE                         1077   2.021055
# ATTIVITÀ FINANZIARIE E ASSICURATIVE                   718   1.347370
# FORNITURA DI ENERGIA ELETTRICA, GAS, VAPORE E A...    708   1.328604
# ISTRUZIONE                                            466   0.874477
# ATTIVITÀ ARTISTICHE, SPORTIVE, DI INTRATTENIMEN...    445   0.835069
# FORNITURA DI ACQUA; RETI FOGNARIE, ATTIVITÀ DI ...    434   0.814427
# ALTRE ATTIVITÀ DI SERVIZI                             217   0.407213
# ESTRAZIONE DI MINERALI DA CAVE E MINIERE              153   0.287114
# AMMINISTRAZIONE PUBBLICA E DIFESA; ASSICURAZION...      4   0.007506
# ORGANIZZAZIONI ED ORGANISMI EXTRATERRITORIALI           3   0.005630

# %%
sectors = aida_ateco['desc1'].value_counts()[0:10].index
aida_ateco = aida_ateco.loc[aida_ateco['desc1'].isin(sectors),:]

# %%
def ateco_groupby(df):
    aggregation = {'Comune':[np.size],'ricavi':[np.sum],'dipendenti':[np.sum]}
    ateco0 = df.groupby(['Comune']).aggregate(aggregation).reset_index()
    ateco0.columns = ['Comune','n_imprese','tot_ricavi','tot_dipendenti']
    ateco1 = df.groupby(['Comune', 'ateco1','desc1']).aggregate(aggregation).reset_index()
    ateco1.columns = ['Comune','ateco1','desc1','n_imprese','tot_ricavi','tot_dipendenti']
    ateco2 = df.groupby(['Comune','ateco2','desc2']).aggregate(aggregation).reset_index()
    ateco2.columns = ['Comune','ateco2','desc2','n_imprese','tot_ricavi','tot_dipendenti']
    return (ateco0,ateco1,ateco2)

imprese_ateco0,imprese_ateco1,imprese_ateco2 = ateco_groupby(aida_ateco)

imprese_ateco0.loc[imprese_ateco0['Comune']=='Acciano',:]
# Out:
#     Comune  n_imprese  tot_ricavi  tot_dipendenti
# 1  Acciano          3       166.0             3.0

# %%
imprese_ateco1.loc[imprese_ateco1['Comune']=='Acciano',:]
# Out:
#     Comune ateco1                                              desc1  \
# 2  Acciano      G  COMMERCIO ALL'INGROSSO E AL DETTAGLIO; RIPARAZ...
# 3  Acciano      N  NOLEGGIO, AGENZIE DI VIAGGIO, SERVIZI DI SUPPO...
#
#    n_imprese  tot_ricavi  tot_dipendenti
# 2          2       128.0             2.0
# 3          1        38.0             1.0

# %%
imprese_ateco2.loc[imprese_ateco2['Comune']=='Acciano',:]
# Out:
#     Comune ateco2                                              desc2  \
# 2  Acciano     46  COMMERCIO ALL'INGROSSO (ESCLUSO QUELLO DI AUTO...
# 3  Acciano     81        ATTIVITÀ DI SERVIZI PER EDIFICI E PAESAGGIO
#
#    n_imprese  tot_ricavi  tot_dipendenti
# 2          2       128.0             2.0
# 3          1        38.0             1.0

# %%
# normalizzo per la popolazione

istat = pd.read_csv('quake_data/alldata_reshape.csv')
istat = istat[['Comune','pop_iniz_2016']]
istat
# Out:
#                               Comune  pop_iniz_2016
# 0                            Acciano          335.0
# 1                           Accumoli          655.0
# 2                   Acquasanta Terme         2935.0
# 3                        Acquasparta         4705.0
# 4                   Acquaviva Picena         3829.0
# ..                               ...            ...
# 380                     Varco Sabino          185.0
# 381                        Venarotta         2079.0
# 382                Villa Sant'Angelo          440.0
# 383  Villa Santa Lucia degli Abruzzi          125.0
# 384                            Visso         1108.0
#
# [385 rows x 2 columns]

# %%
imprese_ateco1 = imprese_ateco1.merge(istat)
imprese_ateco1['p_imprese'] = imprese_ateco1['n_imprese'] / imprese_ateco1['pop_iniz_2016']
imprese_ateco1['p_ricavi'] = imprese_ateco1['tot_ricavi'] / imprese_ateco1['pop_iniz_2016']
imprese_ateco1['p_dipendenti'] = imprese_ateco1['tot_dipendenti'] / imprese_ateco1['pop_iniz_2016']
imprese_ateco1
# Out:
#         Comune ateco1                                              desc1  \
# 0      Acciano      G  COMMERCIO ALL'INGROSSO E AL DETTAGLIO; RIPARAZ...
# 1      Acciano      N  NOLEGGIO, AGENZIE DI VIAGGIO, SERVIZI DI SUPPO...
# 2     Accumoli      A                  AGRICOLTURA, SILVICOLTURA E PESCA
# 3     Accumoli      F                                        COSTRUZIONI
# 4     Accumoli      G  COMMERCIO ALL'INGROSSO E AL DETTAGLIO; RIPARAZ...
# ...        ...    ...                                                ...
# 2212     Visso      A                  AGRICOLTURA, SILVICOLTURA E PESCA
# 2213     Visso      C                            ATTIVITÀ MANIFATTURIERE
# 2214     Visso      F                                        COSTRUZIONI
# 2215     Visso      L                              ATTIVITA' IMMOBILIARI
# 2216     Visso      M    ATTIVITÀ PROFESSIONALI, SCIENTIFICHE E TECNICHE
#
#       n_imprese  tot_ricavi  tot_dipendenti  pop_iniz_2016  p_imprese  \
# 0             2       128.0             2.0          335.0   0.005970
# 1             1        38.0             1.0          335.0   0.002985
# 2             5       556.0            12.0          655.0   0.007634
# 3             1         0.0             0.0          655.0   0.001527
# 4             2       847.0             3.0          655.0   0.003053
# ...         ...         ...             ...            ...        ...
# 2212          1         9.0             0.0         1108.0   0.000903
# 2213          1     32359.0           122.0         1108.0   0.000903
# 2214          6      6538.0            50.0         1108.0   0.005415
# 2215          2       227.0             0.0         1108.0   0.001805
# 2216          1       582.0             2.0         1108.0   0.000903
#
#        p_ricavi  p_dipendenti
# 0      0.382090      0.005970
# 1      0.113433      0.002985
# 2      0.848855      0.018321
# 3      0.000000      0.000000
# 4      1.293130      0.004580
# ...         ...           ...
# 2212   0.008123      0.000000
# 2213  29.204874      0.110108
# 2214   5.900722      0.045126
# 2215   0.204874      0.000000
# 2216   0.525271      0.001805
#
# [2217 rows x 10 columns]

# %%
value = 'p_ricavi'
imprese_ateco_wide = imprese_ateco1.pivot(index='Comune',columns='desc1')[value].fillna(0)
imprese_ateco_wide.columns
# Out:
# Index(['AGRICOLTURA, SILVICOLTURA E PESCA', 'ATTIVITA' IMMOBILIARI',
#        'ATTIVITÀ DEI SERVIZI DI ALLOGGIO E DI RISTORAZIONE',
#        'ATTIVITÀ MANIFATTURIERE',
#        'ATTIVITÀ PROFESSIONALI, SCIENTIFICHE E TECNICHE',
#        'COMMERCIO ALL'INGROSSO E AL DETTAGLIO; RIPARAZIONE DI AUTOVEICOLI E MOTOCICLI',
#        'COSTRUZIONI',
#        'NOLEGGIO, AGENZIE DI VIAGGIO, SERVIZI DI SUPPORTO ALLE IMPRESE',
#        'SERVIZI DI INFORMAZIONE E COMUNICAZIONE', 'TRASPORTO E MAGAZZINAGGIO'],
#       dtype='object', name='desc1')

# %%
value = 'p_ricavi'
imprese_ateco_wide = imprese_ateco1.pivot(index='Comune',columns='desc1')[value].fillna(0)
#imprese_ateco_wide = imprese_ateco2.pivot(index='Comune',columns='ateco2')[value].fillna(0)


ateco_names = ['AGRICOLTURE','REAL ESTATE','HOSPITALITY','MANUFACTURING','TECH SERVICES','WHOLE/RETAIL SALES','CONSTRUCTIONS','BUSINESS SUPPORT SERVICES','COMMUNICATION AND INFORMATION SERV.','LOGISTICS']

'''
ateco_names = ['AGRICOLTURE', 'OTHER','PUBLIC ADMINISTRATION','REAL ESTATE',
       'SPORT AND ENTERTAINMENT','HOSPITALITY',
       'FINANCIAL SERVICES', 'MANUFACTURING','TECH SERVICES',
       'WHOLE/RETAIL SALES','CONSTRUCTIONS', 'MINING',
       'WATER AND WASTE DISPOSAL','UTILITIES',
       'EDUCATION','BUSINESS SUPPORT SERVICES',
       'EXTRATERRITORIAL ORG.','SOCIAL WELFARE',
       'COMMUNICATION AND INFORMATION SERV.','LOGISTICS']
'''


imprese_ateco_wide.columns = ateco_names
imprese_ateco_wide = imprese_ateco_wide.reset_index()
imprese_ateco_wide.head(2)
# Out:
#      Comune  AGRICOLTURE  REAL ESTATE  HOSPITALITY  MANUFACTURING  \
# 0   Acciano     0.000000     0.000000          0.0            0.0
# 1  Accumoli     0.848855     0.183206          0.0            0.0
#
#    TECH SERVICES  WHOLE/RETAIL SALES  CONSTRUCTIONS  \
# 0            0.0             0.38209            0.0
# 1            0.0             1.29313            0.0
#
#    BUSINESS SUPPORT SERVICES  COMMUNICATION AND INFORMATION SERV.  LOGISTICS
# 0                   0.113433                                  0.0   0.000000
# 1                   0.000000                                  0.0   0.490076

# %%
imprese_ateco_wide.to_csv('quake_data/imprese_ateco_wide_norm_by_pop.csv',index=False)
