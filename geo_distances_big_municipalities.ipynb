# %% [markdown]
# # Compuates distances between municipalities and big municipalities

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import calendar
import folium
import geopandas as gpd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import math
import folium
import datetime
from os import listdir
from os.path import isfile, join

from matplotlib import gridspec
from matplotlib.backends.backend_pdf import PdfPages

# %%
import matplotlib 
import matplotlib.pyplot as plt

font = {'size'   : 16}

matplotlib.rc('font', **font)

# %%
mymap = gpd.read_file('quake_data/Comuni2016/Com01012016_WGS84.shp',encoding='utf-8').to_crs('epsg:4326')
mymap = mymap[['COD_REG','COMUNE','geometry']]
mymap.columns = ['COD_REG','Comune','geometry']
map_reg = gpd.read_file('quake_data/Reg/Reg01012016_WGS84.shp').to_crs('epsg:4326')
map_reg = map_reg[map_reg['DEN_REG'].isin(['Marche','Lazio','Abruzzo','Umbria'])]
map_reg = map_reg[['COD_REG','DEN_REG','geometry']]
map_reg.columns = ['COD_REG','Regione','geometry']
map_reg.head(2)
# Out:
#     COD_REG Regione                                           geometry
# 9        10  Umbria  MULTIPOLYGON (((12.35804 43.61649, 12.35857 43...
# 10       11  Marche  POLYGON ((12.75621 43.96864, 12.75644 43.96851...

# %%
mapx = mymap.merge(map_reg[['COD_REG','Regione']])
mapx
# Out:
#       COD_REG               Comune  \
# 0          11         Ripatransone
# 1          11          Trecastelli
# 2          11        Massa Fermana
# 3          11  Monsampietro Morico
# 4          11          Servigliano
# ...       ...                  ...
# 1006       12      Castel Gandolfo
# 1007       12       Olevano Romano
# 1008       12              Percile
# 1009       12            Pisoniano
# 1010       12          Concerviano
#
#                                                geometry Regione
# 0     POLYGON ((13.79857 43.03372, 13.79856 43.03366...  Marche
# 1     POLYGON ((13.11299 43.72705, 13.11340 43.72703...  Marche
# 2     POLYGON ((13.47962 43.16622, 13.47990 43.16615...  Marche
# 3     POLYGON ((13.56050 43.08014, 13.56080 43.07984...  Marche
# 4     POLYGON ((13.51740 43.08507, 13.51762 43.08429...  Marche
# ...                                                 ...     ...
# 1006  POLYGON ((12.66254 41.76413, 12.66487 41.76384...   Lazio
# 1007  POLYGON ((13.02449 41.87244, 13.02484 41.87216...   Lazio
# 1008  POLYGON ((12.92084 42.11524, 12.92112 42.11408...   Lazio
# 1009  POLYGON ((12.95544 41.93072, 12.95859 41.92697...   Lazio
# 1010  MULTIPOLYGON (((12.97936 42.33249, 12.97949 42...   Lazio
#
# [1011 rows x 4 columns]

# %%
alldata = pd.read_csv('quake_data/alldata_reshape.csv')
bigc = alldata.loc[alldata['pop_iniz_2016']>20000,'Comune']
big = mapx.loc[mapx['Comune'].isin(bigc),:]
big['Lon'] = big['geometry'].centroid.x
big['Lat'] = big['geometry'].centroid.y
big_list = big[['Lon','Lat']].values.tolist()
#big = [[big['Lon'].mean(),big['Lat'].mean()]]
big
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_992\3677233725.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big['Lon'] = big['geometry'].centroid.x
# C:\Users\marco\anaconda3\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\marco\AppData\Local\Temp\ipykernel_992\3677233725.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big['Lat'] = big['geometry'].centroid.y
# C:\Users\marco\anaconda3\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#      COD_REG                    Comune  \
# 31        11  San Benedetto del Tronto
# 108       11                  Macerata
# 133       11         Civitanova Marche
# 153       11                  Recanati
# 200       11             Ascoli Piceno
# 206       11                     Fermo
# 214       11        Porto Sant'Elpidio
# 258       10         Città di Castello
# 272       10                    Assisi
# 274       10              Bastia Umbra
# 275       10                   Spoleto
# 282       10                     Terni
# 293       10                   Perugia
# 298       10                    Gubbio
# 318       10                   Foligno
# 323       10                  Corciano
# 326       10                   Orvieto
# 437       13                Giulianova
# 449       13      Roseto degli Abruzzi
# 468       13                    Teramo
# 493       13                  L'Aquila
# 954       12                     Rieti
#
#                                               geometry  Regione        Lon  \
# 31   POLYGON ((13.88232 42.96197, 13.88247 42.96182...   Marche  13.877766
# 108  POLYGON ((13.39618 43.35980, 13.39630 43.35948...   Marche  13.451857
# 133  POLYGON ((13.70400 43.34877, 13.70432 43.34826...   Marche  13.685115
# 153  POLYGON ((13.59330 43.44309, 13.59282 43.44258...   Marche  13.531364
# 200  MULTIPOLYGON (((13.57809 42.92779, 13.57794 42...   Marche  13.568747
# 206  MULTIPOLYGON (((13.78051 43.22809, 13.78059 43...   Marche  13.716904
# 214  POLYGON ((13.75101 43.27995, 13.75216 43.27784...   Marche  13.745010
# 258  MULTIPOLYGON (((12.35804 43.61649, 12.35857 43...   Umbria  12.248559
# 272  POLYGON ((12.68455 43.15656, 12.68492 43.15604...   Umbria  12.625269
# 274  POLYGON ((12.53044 43.08660, 12.53085 43.08575...   Umbria  12.528928
# 275  POLYGON ((12.82273 42.82095, 12.82306 42.82089...   Umbria  12.708057
# 282  POLYGON ((12.64003 42.67306, 12.63990 42.67215...   Umbria  12.660560
# 293  POLYGON ((12.43332 43.28510, 12.43322 43.28456...   Umbria  12.394960
# 298  POLYGON ((12.52217 43.49926, 12.52229 43.49897...   Umbria  12.546576
# 318  POLYGON ((12.80724 43.06242, 12.80755 43.06206...   Umbria  12.790956
# 323  POLYGON ((12.27152 43.19575, 12.27195 43.19571...   Umbria  12.290490
# 326  POLYGON ((12.24443 42.81193, 12.24525 42.81175...   Umbria  12.151846
# 437  POLYGON ((13.95568 42.78117, 13.95584 42.78081...  Abruzzo  13.941213
# 449  POLYGON ((13.98057 42.73936, 13.98063 42.73934...  Abruzzo  13.979476
# 468  POLYGON ((13.77388 42.71322, 13.77409 42.71291...  Abruzzo  13.710671
# 493  MULTIPOLYGON (((13.42351 42.51805, 13.42409 42...  Abruzzo  13.424906
# 954  MULTIPOLYGON (((12.86335 42.48033, 12.86350 42...    Lazio  12.850481
#
#            Lat
# 31   42.929071
# 108  43.303570
# 133  43.313385
# 153  43.401279
# 200  42.851297
# 206  43.160754
# 214  43.255117
# 258  43.444600
# 272  43.086187
# 274  43.064314
# 275  42.737505
# 282  42.579595
# 293  43.136464
# 298  43.331054
# 318  42.976798
# 323  43.128778
# 326  42.734003
# 437  42.741033
# 449  42.681100
# 468  42.658272
# 493  42.393385
# 954  42.405607

# %%
from math import radians, cos, sin, asin, sqrt


def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371  #
    return c * r

def dist(row):
    return min([haversine(row['Lon'],row['Lat'],e[0],e[1]) for e in big_list])


mapx['geometry'] = mapx['geometry'].to_crs('EPSG:4326')
cent = pd.DataFrame({'Comune':mapx['Comune'],'Lon':mapx['geometry'].centroid.x,'Lat':mapx['geometry'].centroid.y})
cent['Distance_from_big'] = cent.apply(dist,axis='columns')
cent = cent[['Comune','Distance_from_big']]
cent
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_992\753111668.py:25: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   cent = pd.DataFrame({'Comune':mapx['Comune'],'Lon':mapx['geometry'].centroid.x,'Lat':mapx['geometry'].centroid.y})
# C:\Users\marco\AppData\Local\Temp\ipykernel_992\753111668.py:25: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   cent = pd.DataFrame({'Comune':mapx['Comune'],'Lon':mapx['geometry'].centroid.x,'Lat':mapx['geometry'].centroid.y})
#                    Comune  Distance_from_big
# 0            Ripatransone          11.503605
# 1             Trecastelli          46.567433
# 2           Massa Fermana          16.838096
# 3     Monsampietro Morico          17.302710
# 4             Servigliano          21.099887
# ...                   ...                ...
# 1006      Castel Gandolfo          75.382137
# 1007       Olevano Romano          63.677936
# 1008              Percile          35.980206
# 1009            Pisoniano          55.937800
# 1010          Concerviano          14.720315
#
# [1011 rows x 2 columns]

# %%
cent.to_csv('quake_data/distance_from_big.csv',index=False)

# %% [markdown]
# ## Visualize

# %%
mymap = gpd.read_file('quake_data/Comuni2016/Com01012016_WGS84.shp',encoding='utf-8').to_crs('epsg:4326')
mymap = mymap[['COD_REG','COMUNE','geometry']]
mymap.columns = ['COD_REG','Comune','geometry']
map_reg = gpd.read_file('quake_data/Reg/Reg01012016_WGS84.shp').to_crs('epsg:4326')
map_reg = map_reg[map_reg['DEN_REG'].isin(['Marche','Lazio','Abruzzo','Umbria'])]
map_reg = map_reg[['COD_REG','DEN_REG','geometry']]
map_reg.columns = ['COD_REG','Regione','geometry']
map_reg.head()
# Out:
#     COD_REG  Regione                                           geometry
# 9        10   Umbria  MULTIPOLYGON (((12.35804 43.61649, 12.35857 43...
# 10       11   Marche  POLYGON ((12.75621 43.96864, 12.75644 43.96851...
# 11       12    Lazio  MULTIPOLYGON (((12.24362 41.73787, 12.24419 41...
# 12       13  Abruzzo  MULTIPOLYGON (((14.23309 42.46541, 14.23313 42...

# %%
cent = pd.read_csv('quake_data/distance_from_big.csv')
cent
# Out:
#                    Comune  Distance_from_big
# 0            Ripatransone          11.503605
# 1             Trecastelli          46.567433
# 2           Massa Fermana          16.838096
# 3     Monsampietro Morico          17.302710
# 4             Servigliano          21.099887
# ...                   ...                ...
# 1006      Castel Gandolfo          75.382137
# 1007       Olevano Romano          63.677936
# 1008              Percile          35.980206
# 1009            Pisoniano          55.937800
# 1010          Concerviano          14.720315
#
# [1011 rows x 2 columns]

# %%
mapx = mymap.merge(cent).merge(map_reg[['COD_REG','Regione']])
mapx.head()
# Out:
#    COD_REG               Comune  \
# 0       11         Ripatransone
# 1       11          Trecastelli
# 2       11        Massa Fermana
# 3       11  Monsampietro Morico
# 4       11          Servigliano
#
#                                             geometry  Distance_from_big  \
# 0  POLYGON ((13.79857 43.03372, 13.79856 43.03366...          11.503605
# 1  POLYGON ((13.11299 43.72705, 13.11340 43.72703...          46.567433
# 2  POLYGON ((13.47962 43.16622, 13.47990 43.16615...          16.838096
# 3  POLYGON ((13.56050 43.08014, 13.56080 43.07984...          17.302710
# 4  POLYGON ((13.51740 43.08507, 13.51762 43.08429...          21.099887
#
#   Regione
# 0  Marche
# 1  Marche
# 2  Marche
# 3  Marche
# 4  Marche

# %%
plt.figure(figsize = (20, 4))
mapx.plot(column='Distance_from_big', cmap = 'brg', legend= True)
plt.title('Distance from big (Km)',fontsize=11)
plt.show()
